# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_original = pd.read_csv(r"..\1_Data\AmesHousing.csv")

# %%
new_column_names = {
    # ID & Location
    "Order": "id",
    "PID": "parcel_id",
    "MS SubClass": "dwelling_class",
    "MS Zoning": "zoning",
    "Lot Frontage": "lot_frontage",
    "Lot Area": "lot_area",
    "Street": "street_type",
    "Alley": "alley_access",
    "Lot Shape": "lot_shape",
    "Land Contour": "land_contour",
    "Utilities": "utilities",
    "Lot Config": "lot_config",
    "Land Slope": "land_slope",
    "Neighborhood": "neighborhood",
    "Condition 1": "proximity_1",
    "Condition 2": "proximity_2",
    
    # Building Specs
    "Bldg Type": "building_type",
    "House Style": "house_style",
    "Overall Qual": "overall_quality",
    "Overall Cond": "overall_condition",
    "Year Built": "year_built",
    "Year Remod/Add": "year_remodeled",
    "Roof Style": "roof_style",
    "Roof Matl": "roof_material",
    "Exterior 1st": "exterior_1",
    "Exterior 2nd": "exterior_2",
    "Mas Vnr Type": "masonry_type",
    "Mas Vnr Area": "masonry_area",
    "Exter Qual": "exterior_quality",
    "Exter Cond": "exterior_condition",
    "Foundation": "foundation",
    
    # Basement
    "Bsmt Qual": "bsmt_height",
    "Bsmt Cond": "bsmt_condition",
    "Bsmt Exposure": "bsmt_exposure",
    "BsmtFin Type 1": "bsmt_fin_type_1",
    "BsmtFin SF 1": "bsmt_fin_area_1",
    "BsmtFin Type 2": "bsmt_fin_type_2",
    "BsmtFin SF 2": "bsmt_fin_area_2",
    "Bsmt Unf SF": "bsmt_unfinshed_area",
    "Total Bsmt SF": "total_bsmt_area",
    
    # Systems
    "Heating": "heating_type",
    "Heating QC": "heating_quality",
    "Central Air": "central_air",
    "Electrical": "electrical",
    
    # Floor Space (Above Ground)
    "1st Flr SF": "first_floor_area",
    "2nd Flr SF": "second_floor_area",
    "Low Qual Fin SF": "low_qual_area",
    "Gr Liv Area": "above_grade_living_area",
    
    # Bathrooms
    "Bsmt Full Bath": "bsmt_full_bath",
    "Bsmt Half Bath": "bsmt_half_bath",
    "Full Bath": "full_bath",
    "Half Bath": "half_bath",
    
    # Rooms
    "Bedroom AbvGr": "bedrooms_above_grade",
    "Kitchen AbvGr": "kitchens_above_grade",
    "Kitchen Qual": "kitchen_quality",
    "TotRms AbvGrd": "total_rooms_above_grade",
    "Functional": "functionality",
    "Fireplaces": "fireplaces",
    "Fireplace Qu": "fireplace_quality",
    
    # Garage
    "Garage Type": "garage_type",
    "Garage Yr Blt": "garage_year_built",
    "Garage Finish": "garage_finish",
    "Garage Cars": "garage_car_capacity",
    "Garage Area": "garage_area",
    "Garage Qual": "garage_quality",
    "Garage Cond": "garage_condition",
    
    # Outdoor / Decks
    "Paved Drive": "paved_driveway",
    "Wood Deck SF": "wood_deck_area",
    "Open Porch SF": "open_porch_area",
    "Enclosed Porch": "enclosed_porch_area",
    "3Ssn Porch": "three_season_porch_area",
    "Screen Porch": "screen_porch_area",
    "Pool Area": "pool_area",
    "Pool QC": "pool_quality",
    "Fence": "fence_quality",
    "Misc Feature": "misc_feature",
    "Misc Val": "misc_value",
    
    # Sales
    "Mo Sold": "month_sold",
    "Yr Sold": "year_sold",
    "Sale Type": "sale_type",
    "Sale Condition": "sale_condition",
    "SalePrice": "sale_price"
}

df = df_original.rename(columns=new_column_names)

# %%
# df_original
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#         id  parcel_id  dwelling_class zoning  lot_frontage  lot_area  \
# 0        1  526301100              20     RL         141.0     31770
# 1        2  526350040              20     RH          80.0     11622
# 2        3  526351010              20     RL          81.0     14267
# 3        4  526353030              20     RL          93.0     11160
# 4        5  527105010              60     RL          74.0     13830
# ...    ...        ...             ...    ...           ...       ...
# 2925  2926  923275080              80     RL          37.0      7937
# 2926  2927  923276100              20     RL           NaN      8885
# 2927  2928  923400125              85     RL          62.0     10441
# 2928  2929  924100070              20     RL          77.0     10010
# 2929  2930  924151050              60     RL          74.0      9627
#
#      street_type alley_access lot_shape land_contour utilities lot_config  \
# ...

# %%
df.isnull().sum().head(50)
# Out:
# id                            0
# parcel_id                     0
# dwelling_class                0
# zoning                        0
# lot_frontage                490
# lot_area                      0
# street_type                   0
# alley_access               2732
# lot_shape                     0
# land_contour                  0
# utilities                     0
# lot_config                    0
# land_slope                    0
# neighborhood                  0
# proximity_1                   0
# proximity_2                   0
# building_type                 0
# house_style                   0
# overall_quality               0
# overall_condition             0
# year_built                    0
# year_remodeled                0
# roof_style                    0
# roof_material                 0
# exterior_1                    0
# exterior_2                    0
# masonry_type               1775
# masonry_area                 23
# exterior_quality              0
# ...

# %%
df.describe()
# Out:
#                id     parcel_id  dwelling_class  lot_frontage       lot_area  \
# count  2930.00000  2.930000e+03     2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08       57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08       42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08       20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08       20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08       50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08       70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09      190.000000    313.000000  215245.000000
#
#        overall_quality  overall_condition   year_built  year_remodeled  \
# count      2930.000000        2930.000000  2930.000000     2930.000000
# mean          6.094881           5.563140  1971.356314     1984.266553
# ...

# %%
df.nunique().head(90)
# Out:
# id                2930
# parcel_id         2930
# dwelling_class      16
# zoning               7
# lot_frontage       128
#                   ...
# month_sold          12
# year_sold            5
# sale_type           10
# sale_condition       6
# sale_price        1032
# Length: 82, dtype: int64

# %%
df.shape
# Out:
# (2930, 82)
